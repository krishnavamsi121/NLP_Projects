# %%
import pandas as pd
import numpy as np

# %%
df_1 = pd.read_csv('Reviews.csv')
df_1.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %%
df = pd.read_csv(r'Reviews.csv')
df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %%
df.columns
# Out:
# Index(['Id', 'ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator',
#        'HelpfulnessDenominator', 'Score', 'Time', 'Summary', 'Text',
#        'Helpful%', '%upvote'],
#       dtype='object')

# %% [markdown]
# ### 1. Perform data preprocessing and Data preparation for Modelling

# %%
df['Helpful%'] = np.where(df['HelpfulnessDenominator']>0, df['HelpfulnessNumerator']/df['HelpfulnessDenominator'],-1)

# %%
df['Helpful%'].unique()
# Out:
# array([ 1.        , -1.        ,  0.8       ,  0.        ,  0.5       ,
#         0.66666667,  0.25      ,  0.89473684,  0.83333333,  0.75      ,
#         0.33333333,  0.3       ,  0.11111111,  0.42857143,  0.875     ,
#         0.85714286,  0.2       ,  0.26315789,  0.6       ,  0.71428571,
#         0.53846154,  0.57142857,  0.91489362,  0.86666667,  0.82352941,
#         0.78571429,  0.74074074,  0.4       ,  0.375     ,  0.28571429,
#         0.14285714,  0.77777778,  0.125     ,  0.9       ,  0.94117647,
#         0.92307692,  0.7       ,  0.45454545,  0.88888889,  0.83870968,
#         0.9047619 ,  0.92857143,  0.90909091,  0.91666667,  0.84615385,
#         0.10526316,  0.98214286,  0.97826087,  0.7518797 ,  0.3125    ,
#         0.1       ,  0.18518519,  0.88      ,  0.69230769,  0.625     ,
#         0.54545455,  0.41666667,  0.45833333,  0.22222222,  0.81818182,
#         0.8125    ,  0.16666667,  0.93103448,  0.88235294,  0.23529412,
# ...

# %%
df['%upvote'] = pd.cut(df['Helpful%'],bins=[-1,0,0.2,0.4,0.6,0.8,1],labels=['Empty','0-20%','20-40%','40-60%','60-80%','80-100%'])

# %%
df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text  \
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %% [markdown]
# ### 2.1 Analyse upvotes on different scores

# %%
df.groupby(['Score','%upvote']).count()
# Out:
#                    Id  ProductId  UserId  ProfileName  HelpfulnessNumerator  \
# Score %upvote
# 1     Empty      8060       8060    8060         8060                  8060
#       0-20%      2338       2338    2338         2338                  2338
#       20-40%     4649       4649    4649         4649                  4649
#       40-60%     6586       6586    6586         6586                  6586
#       60-80%     5838       5838    5838         5836                  5838
#       80-100%   12531      12531   12531        12531                 12531
# 2     Empty      4234       4234    4234         4234                  4234
#       0-20%       762        762     762          762                   762
#       20-40%     1618       1618    1618         1618                  1618
#       40-60%     3051       3051    3051         3051                  3051
#       60-80%     2486       2486    2486         2486                  2486
# ...

# %% [markdown]
# ### 2.2 Create pivot table and heatmap of above problem statements

# %%
df.groupby(['Score','%upvote']).agg({'Id':'count'})
# Out:
#                    Id
# Score %upvote
# 1     Empty      8060
#       0-20%      2338
#       20-40%     4649
#       40-60%     6586
#       60-80%     5838
#       80-100%   12531
# 2     Empty      4234
#       0-20%       762
#       20-40%     1618
#       40-60%     3051
#       60-80%     2486
#       80-100%    7014
# 3     Empty      5062
#       0-20%       474
#       20-40%     1506
#       40-60%     3384
#       60-80%     2754
#       80-100%   11037
# 4     Empty      4780
#       0-20%       116
#       20-40%      909
#       40-60%     3185
#       60-80%     2941
#       80-100%   26707
# 5     Empty     11638
#       0-20%       432
#       20-40%     2275
#       40-60%    10312
#       60-80%    11060
#       80-100%  140661

# %%
df_s = df.groupby(['Score','%upvote']).agg({'Id':'count'}).reset_index()
df_s
# Out:
#     Score  %upvote      Id
# 0       1    Empty    8060
# 1       1    0-20%    2338
# 2       1   20-40%    4649
# 3       1   40-60%    6586
# 4       1   60-80%    5838
# 5       1  80-100%   12531
# 6       2    Empty    4234
# 7       2    0-20%     762
# 8       2   20-40%    1618
# 9       2   40-60%    3051
# 10      2   60-80%    2486
# 11      2  80-100%    7014
# 12      3    Empty    5062
# 13      3    0-20%     474
# 14      3   20-40%    1506
# 15      3   40-60%    3384
# 16      3   60-80%    2754
# 17      3  80-100%   11037
# 18      4    Empty    4780
# 19      4    0-20%     116
# 20      4   20-40%     909
# 21      4   40-60%    3185
# 22      4   60-80%    2941
# 23      4  80-100%   26707
# 24      5    Empty   11638
# 25      5    0-20%     432
# 26      5   20-40%    2275
# 27      5   40-60%   10312
# 28      5   60-80%   11060
# 29      5  80-100%  140661

# %%
pivot = df_s.pivot(index='%upvote',columns = 'Score')
pivot
# Out:
#             Id
# Score        1     2      3      4       5
# %upvote
# Empty     8060  4234   5062   4780   11638
# 0-20%     2338   762    474    116     432
# 20-40%    4649  1618   1506    909    2275
# 40-60%    6586  3051   3384   3185   10312
# 60-80%    5838  2486   2754   2941   11060
# 80-100%  12531  7014  11037  26707  140661

# %%
import seaborn as sns

# %%
sns.heatmap(pivot,annot=True, cmap='YlGnBu')
# Out:
# <AxesSubplot:xlabel='None-Score', ylabel='%upvote'>

# %% [markdown]
# ### 3.1 Apply Bag of Words on your data

# %%
df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text  \
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %%
df['Score'].unique()
# Out:
# array([5, 1, 4, 2, 3], dtype=int64)

# %%
df_filtered = df[df['Score']!=3]

# %%
X = df_filtered['Text']

# %%
df_filtered['Score'].unique()
# Out:
# array([5, 1, 4, 2], dtype=int64)

# %%
y_dict = {1:0,2:0,4:1,5:1}
y = df_filtered['Score'].map(y_dict)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
c = CountVectorizer(stop_words='english')

# %%
X_c = c.fit_transform(X)

# %%
X_c.shape
# Out:
# (525814, 114969)

# %% [markdown]
# ### 3.2 Check Model Accuracy

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_c, y)

# %%
X_train.shape
# Out:
# (394360, 114969)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
ml = lr.fit(X_train,y_train)
# Out:
# C:\Users\vamsi\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,

# %%
ml.score(X_test,y_test)
# Out:
# 0.9373621190682673

# %%
predict = ml.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(confusion_matrix(y_test,predict))
print(classification_report(y_test,predict))
# Out:
# [[ 14941   5390]
#  [  2844 108279]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.73      0.78     20331
#            1       0.95      0.97      0.96    111123
#
#     accuracy                           0.94    131454
#    macro avg       0.90      0.85      0.87    131454
# weighted avg       0.94      0.94      0.94    131454

# %% [markdown]
# ### 3.3 Fetch Top 20 Positive Words & Top 20 Negative Words

# %%
w = c.get_feature_names()
w
# Out:
# C:\Users\vamsi\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['00',
#  '000',
#  '0000',
#  '000001',
#  '00001',
#  '000013',
#  '0000soo',
#  '0001',
#  '000111052',
#  '0002251337',
#  '0003',
#  '0004',
#  '000iu',
#  '000kwh',
#  '000mg',
#  '000mi',
#  '000s',
#  '000su',
#  '000usd',
#  '000v',
#  '001',
#  '00100',
#  '00127',
#  '00128',
#  '00129',
#  '00130',
#  '00131',
#  '00132',
#  '00134',
#  '00136',
#  '00139',
#  '001bru',
#  '002',
#  '0020100604',
#  '00202',
#  '00227',
#  '0023',
#  '003',
#  '004',
#  '00493',
#  '005',
#  '00533',
#  '0060187654',
#  '0060721855',
#  '0060928115',
#  '0060959584',
#  '0061658197',
#  '006176793x',
#  '0067575986',
#  '0069615',
#  '007',
#  '00703',
#  '00704',
#  '0071468633',
#  '0071477845',
# ...

# %%
coef = ml.coef_.tolist()[0]
coef
# Out:
# [-0.29973068921235374,
#  -0.05324653343220591,
#  0.48001157161697255,
#  -0.007602370997703195,
#  -0.01025191169778931,
#  -0.015292238860900097,
#  0.00040453330689261597,
#  -0.013033722219662017,
#  0.00046721537747676343,
#  0.00044825495130586214,
#  0.0,
#  -0.009889092955234635,
#  0.0014253741038965154,
#  0.01699622605274222,
#  -0.3985912995686619,
#  0.0028031217051912778,
#  0.001696654440907292,
#  0.0036283639586313066,
#  0.0010559480510446463,
#  5.248186566982245e-05,
#  0.12612032692471642,
#  0.031978914738965795,
#  0.0369726831854783,
#  0.0369726831854783,
#  0.0369726831854783,
#  0.0369726831854783,
#  0.0369726831854783,
#  0.0369726831854783,
#  0.0369726831854783,
#  0.0369726831854783,
#  0.0369726831854783,
#  -0.00046799625383635616,
#  0.05842804524805999,
#  0.00012494912679077494,
#  -0.10819433230995322,
#  -0.0005350925313407748,
#  0.00011691142316242411,
#  0.004175576017247117,
#  0.058184035282245104,
#  0.0,
#  -0.10871200258586278,
#  0.0,
# ...

# %%
coef_df = pd.DataFrame({'Word':w,'Coefficient':coef})
coef_df
# Out:
#           Word  Coefficient
# 0           00    -0.299731
# 1          000    -0.053247
# 2         0000     0.480012
# 3       000001    -0.007602
# 4        00001    -0.010252
# ...        ...          ...
# 114964  çaykur     0.000735
# 114965   çelem    -0.147441
# 114966    être     0.016661
# 114967     île     0.011704
# 114968      ît     0.000432
#
# [114969 rows x 2 columns]

# %%
coef_df.sort_values(['Coefficient','Word'])
# Out:
#                  Word  Coefficient
# 107383    undrinkable    -3.491344
# 34989       deceptive    -3.434598
# 113164          worst    -3.300209
# 37560   disappointing    -3.298261
# 106852   unacceptable    -3.158690
# ...               ...          ...
# 94667       skeptical     2.423166
# 87967          resist     2.597237
# 5865        addicting     2.620154
# 39072        downside     2.872928
# 80600      pleasantly     3.863811
#
# [114969 rows x 2 columns]

# %%
coef_df = coef_df.sort_values(['Coefficient','Word'],ascending=False)

# %%
coef_df.head(20)
# Out:
#               Word  Coefficient
# 80600   pleasantly     3.863811
# 39072     downside     2.872928
# 5865     addicting     2.620154
# 87967       resist     2.597237
# 94667    skeptical     2.423166
# 113138     worries     2.378392
# 35726       delish     2.316892
# 24746         calm     2.310298
# 87174     relaxing     2.282468
# 39214     drawback     2.270777
# 55029       hooked     2.128395
# 35691    delighted     2.105091
# 102857    terrific     2.097044
# 54130     hesitant     2.080750
# 40342   economical     2.066599
# 68460          met     2.061432
# 96353     soothing     2.059881
# 111911        whim     2.046972
# 96140       solved     2.021773
# 40135      easiest     2.021769

# %%
coef_df.tail(20)
# Out:
#                   Word  Coefficient
# 110404         vomited    -2.312837
# 106894     unappealing    -2.353621
# 67898         mediocre    -2.407582
# 65064            lousy    -2.410926
# 96502          sounded    -2.413038
# 62401           lacked    -2.415383
# 41118      embarrassed    -2.493090
# 76576       overpowers    -2.538169
# 89868            ruins    -2.546017
# 37528      disapointed    -2.573411
# 35220          defeats    -2.642857
# 24949        cancelled    -2.647582
# 88351       returnable    -2.698533
# 37563   disappointment    -2.715410
# 88945           ripoff    -2.791039
# 106852    unacceptable    -3.158690
# 37560    disappointing    -3.298261
# 113164           worst    -3.300209
# 34989        deceptive    -3.434598
# 107383     undrinkable    -3.491344

# %% [markdown]
# ### 4. Automate the following
# ### 4.1 Apply Bag of Words on data
# ### 4.2 Check Model Accuracy
# ### 4.3 Fetch Top 20 Positive words & Top 20 Negative words

# %%
def text_fit(X,y,nlp_model,ml_model,coef_show=1):
    X_c = nlp_model.fit_transform(X)
    print('features:{}'.format(X_c.shape[1]))
    X_train, X_test, y_train, y_test = train_test_split(X_c, y)
    ml = ml_model.fit(X_train,y_train)
    acc = ml.score(X_test,y_test)
    print(acc)
    
    if coef_show == 1:
        w = c.get_feature_names()
        coef = ml.coef_.tolist()[0]
        coef_df = pd.DataFrame({'Word':w,'Coefficient':coef})
        coef_df = coef_df.sort_values(['Coefficient','Word'],ascending=False)
        print('\n')
        print('Top 20 Positive Words')
        print(coef_df.head(20))
        print('\n')
        print('Top 20 Negative Words')
        print(coef_df.tail(20))

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
c = CountVectorizer(stop_words='english')

# %%
from sklearn.linear_model import LogisticRegression

# %%
text_fit(X,y,c,LogisticRegression(),1)
# Out:
# features:114969
# C:\Users\vamsi\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# C:\Users\vamsi\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# 0.9359471754377957
#
#
# Top 20 Positive Words
#               Word  Coefficient
# 80600   pleasantly     4.085826
# ...

# %% [markdown]
# ### 5. Automate the Predictions

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
def predict(X,y,nlp_model,ml_model):
    X_c = nlp_model.fit_transform(X)
    X_train, X_test, y_train, y_test = train_test_split(X_c, y)
    ml = ml_model.fit(X_train,y_train)
    predictions = ml.predict(X_test)
    print(confusion_matrix(y_test,predictions))
    print('\n')
    print(accuracy_score(y_test,predictions))

# %%
c = CountVectorizer(stop_words='english')
lr = LogisticRegression()

# %%
predict(X,y,c,lr)
# Out:
# [[ 14902   5634]
#  [  2799 108119]]
#
#
# 0.9358482815281391
# C:\Users\vamsi\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
